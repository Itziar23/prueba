# %% [markdown]
# <a href="https://colab.research.google.com/github/Itziar23/prueba/blob/master/Copia_de_Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
ruta='gdrive/My Drive/Colab Notebooks/patient0001'
# Out:
# Mounted at /content/gdrive

# %%
pip install SimpleITK
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting SimpleITK
#   Downloading SimpleITK-2.2.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (52.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 MB 8.3 MB/s eta 0:00:00
# Installing collected packages: SimpleITK
# Successfully installed SimpleITK-2.2.1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import SimpleITK as sitk
import os

# %matplotlib inline

# %%
print(os.getcwd())
# Out:
# /content

# %%
fig_size = plt.rcParams["figure.figsize"]

fig_size[0] = 7
fig_size[1] = 9
plt.rcParams["figure.figsize"] = fig_size

# %%
train_path = "gdrive/My Drive/Colab Notebooks/patient0001/"

# %%
def mhd_to_array(path):
    """
    Read an *.mhd file stored in path and return it as a numpy array.
    """
    return sitk.GetArrayFromImage(sitk.ReadImage(path, sitk.sitkFloat32))

# %%
image = sitk.GetArrayFromImage(sitk.ReadImage(train_path + "patient0001_2CH_ED.mhd", sitk.sitkFloat32))
mask = sitk.GetArrayFromImage(sitk.ReadImage(train_path + "patient0001_2CH_ED_gt.mhd", sitk.sitkFloat32))

# %%
np.shape(image)
# Out:
# (1, 778, 549)

# %%
np.shape(mask)
# Out:
# (1, 778, 549)

# %%
fig, ax = plt.subplots(2)
ax[0].imshow(image[0]) # End Diastolic frame
ax[1].imshow(mask[0]) # End Diastolic mask
plt.show()
